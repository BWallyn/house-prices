# %% [markdown]
# # Analyze data

# %% [markdown]
# # 1. Imports
# ## 1.1 Packages

# %%
# Essentials
import pandas as pd

# Stats
from scipy.stats import skew, norm

# Plots
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# ## 1.2 Options

# %%
# Pandas option
pd.options.display.max_columns = 100

# Plots option
sns.set_style("white")
sns.set_color_codes(palette='deep')

import warnings
warnings.simplefilter('ignore', FutureWarning)

# %% [markdown]
# ## 1.3 Dataset

# %%
df_train = pd.read_csv('../data/01_raw/train.csv', index_col='Id')

# %%
df_train
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# ...

# %% [markdown]
# # 2. Analyze

# %%
df_train.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315
# std      30.202904     20.645407   181.066207   456.098091   161.319273
# ...

# %% [markdown]
# ## 2.1 NaNs

# %%
(df_train.isna().sum() / df_train.shape[0]).sort_values(ascending=False).head(25)
# Out:
# PoolQC          0.995205
# MiscFeature     0.963014
# Alley           0.937671
# Fence           0.807534
# MasVnrType      0.597260
# FireplaceQu     0.472603
# LotFrontage     0.177397
# GarageYrBlt     0.055479
# GarageCond      0.055479
# GarageType      0.055479
# GarageFinish    0.055479
# GarageQual      0.055479
# BsmtExposure    0.026027
# BsmtFinType2    0.026027
# BsmtCond        0.025342
# BsmtQual        0.025342
# BsmtFinType1    0.025342
# MasVnrArea      0.005479
# Electrical      0.000685
# MSSubClass      0.000000
# Fireplaces      0.000000
# Functional      0.000000
# KitchenQual     0.000000
# KitchenAbvGr    0.000000
# BedroomAbvGr    0.000000
# dtype: float64

# %%
df_train["Functional"].value_counts(dropna=False)
# Out:
# Functional
# Typ     1360
# Min2      34
# Min1      31
# Mod       15
# Maj1      14
# Maj2       5
# Sev        1
# Name: count, dtype: int64

# %% [markdown]
# ## 2.2 All features

# %%
df_num = df_train.select_dtypes(include=['int16', 'int32', 'int64', 'float16', 'float32', 'float64'])
df_num.head()
# Out:
#     MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# Id
# 1           60         65.0     8450            7            5       2003
# 2           20         80.0     9600            6            8       1976
# 3           60         68.0    11250            7            5       2001
# 4           70         60.0     9550            7            5       1915
# 5           60         84.0    14260            8            5       2000
#
#     YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# Id
# 1           2003       196.0         706           0        150          856
# 2           1976         0.0         978           0        284         1262
# 3           2002       162.0         486           0        434          920
# 4           1970         0.0         216           0        540          756
# 5           2000       350.0         655           0        490         1145
#
# ...

# %%
df_num.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8);

# %%
df_cat = df_train.select_dtypes(exclude=['int16', 'int32', 'int64', 'float16', 'float32', 'float64'])
df_cat.describe()
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1460   1460    91     1460        1460      1460      1460
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1151   1454    50      925        1311      1459      1052
#
#        LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# count       1460         1460       1460       1460     1460       1460
# unique         3           25          9          8        5          8
# top          Gtl        NAmes       Norm       Norm     1Fam     1Story
# freq        1382          225       1260       1445     1220        726
#
#        RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType ExterQual  \
# count       1460     1460        1460        1460        588      1460
# unique         6        8          15          16          3         4
# ...

# %%
df_cat["Electrical"].value_counts(dropna=False)
# Out:
# Electrical
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# NaN         1
# Name: count, dtype: int64

# %% [markdown]
# ## 2.3 Correlation

# %%
corr = df_num.corr()
plt.subplots(figsize=(15,12))
sns.heatmap(corr, vmax=0.9, cmap="Blues", square=True)
# Out:
# <Axes: >

# %% [markdown]
# ## 2.4 Target

# %%
df_train['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
# Skew and kurt
print("Skewness: %f" % df_train['SalePrice'].skew())
print("Kurtosis: %f" % df_train['SalePrice'].kurt())
# Out:
# Skewness: 1.882876
# Kurtosis: 6.536282

# %%
sns.histplot(df_train['SalePrice'], color='b', bins=100, kde=True);

# %%
sns.scatterplot(df_train, x='LotArea', y='SalePrice', alpha=0.3)
# Out:
# <Axes: xlabel='LotArea', ylabel='SalePrice'>

# %%
data = pd.concat([df_train['SalePrice'], df_train['TotalBsmtSF']], axis=1)
data.plot.scatter(x='TotalBsmtSF', y='SalePrice', alpha=0.3, ylim=(0,800000));

# %%
data = pd.concat([df_train['SalePrice'], df_train['GrLivArea']], axis=1)
data.plot.scatter(x='GrLivArea', y='SalePrice', alpha=0.3, ylim=(0,800000));

# %%
data = pd.concat([df_train["SalePrice"], df_train["OverallQual"]], axis=1)
f, ax = plt.subplots(figsize=(6, 4))
fig = sns.boxplot(x=df_train["OverallQual"], y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);
