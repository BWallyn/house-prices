# %% [markdown]
# # Create model
#
# # 1. Imports
#
# ## 1.1 Packages

# %%
# Essentials
import os
import pandas as pd
import sys

# Machine learning
from hyperopt import hp

# %%
sys.path.append('../src/house_prices/pipelines/data_science/')
from nodes import feature_engineering, feature_imputer, column_transformer, pipe_estimator
from class_hyperopt import hyperopt_mlflow

# %% [markdown]
# ## 1.2 Options

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Pandas option
pd.options.display.max_columns = 100

# %%
path_data = '../data/03_primary/'

# %% [markdown]
# ## 1.3 Dataset

# %%
df_train = pd.read_pickle(os.path.join(path_data, 'train_split.pkl'))
df_valid = pd.read_pickle(os.path.join(path_data, 'valid_split.pkl'))
df_train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1023  1024         120       RL         43.0     3182   Pave   NaN      Reg
# 810    811          20       RL         78.0    10140   Pave   NaN      Reg
# 1384  1385          50       RL         60.0     9060   Pave   NaN      Reg
# 626    627          20       RL          NaN    12342   Pave   NaN      IR1
# 813    814          20       RL         75.0     9750   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1095  1096          20       RL         78.0     9317   Pave   NaN      IR1
# 1130  1131          50       RL         65.0     7804   Pave   NaN      Reg
# 1294  1295          20       RL         60.0     8172   Pave   NaN      Reg
# 860    861          50       RL         55.0     7642   Pave   NaN      Reg
# 1126  1127         120       RL         53.0     3684   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1023         Lvl    AllPub    Inside       Gtl      Blmngtn       Norm
# 810          Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 1384         Lvl    AllPub    Inside       Gtl      Edwards       Norm
# 626          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 813          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# ...          ...       ...       ...       ...          ...        ...
# 1095         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1130         Lvl    AllPub    Inside       Gtl        SWISU       Norm
# 1294         Lvl    AllPub    Inside       Gtl      Edwards       Norm
# 860          Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 1126         Lvl    AllPub    Inside       Gtl      Blmngtn       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 1023       Norm   TwnhsE     1Story            7            5       2005
# 810        Norm     1Fam     1Story            6            6       1974
# 1384       Norm     1Fam     1.5Fin            6            5       1939
# 626        Norm     1Fam     1Story            5            5       1960
# 813        Norm     1Fam     1Story            6            6       1958
# ...         ...      ...        ...          ...          ...        ...
# 1095       Norm     1Fam     1Story            6            5       2006
# 1130       Norm     1Fam     1.5Fin            4            3       1928
# 1294       Norm     1Fam     1Story            5            7       1955
# 860        Norm     1Fam     1.5Fin            7            8       1918
# 1126       Norm   TwnhsE     1Story            7            5       2007
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 1023          2006     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 810           1999       Hip  CompShg     HdBoard     HdBoard    BrkFace
# 1384          1950     Gable  CompShg     WdShing     Wd Shng        NaN
# 626           1978       Hip  CompShg     Wd Sdng     Wd Sdng        NaN
# 813           1958     Gable  CompShg     MetalSd     MetalSd    BrkFace
# ...            ...       ...      ...         ...         ...        ...
# 1095          2006     Gable  CompShg     VinylSd     VinylSd        NaN
# 1130          1950     Gable  CompShg     WdShing     Plywood        NaN
# 1294          1990       Hip  CompShg     WdShing     Plywood        NaN
# 860           1998     Gable  CompShg     Wd Sdng     Wd Sdng        NaN
# 1126          2007       Hip  CompShg     VinylSd     VinylSd    BrkFace
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 1023        14.0        Gd        TA      PConc       Gd       Gd
# 810         99.0        TA        TA     CBlock       TA       TA
# 1384         0.0        TA        TA     BrkTil       TA       TA
# 626          0.0        TA        TA     CBlock       TA       TA
# 813        243.0        TA        TA     CBlock       TA       TA
# ...          ...       ...       ...        ...      ...      ...
# 1095         0.0        Gd        TA      PConc       Gd       TA
# 1130         0.0        TA        TA     BrkTil       TA       TA
# 1294         0.0        TA        TA     CBlock       TA       TA
# 860          0.0        Gd        TA     BrkTil       TA       TA
# 1126       130.0        Gd        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 1023           No          GLQ          16          Unf           0
# 810            No          ALQ         663          LwQ         377
# 1384           Mn          Rec         204          Unf           0
# 626            No          Unf           0          Unf           0
# 813            No          Rec         608          Unf           0
# ...           ...          ...         ...          ...         ...
# 1095           No          GLQ          24          Unf           0
# 1130           No          BLQ         622          Unf           0
# 1294           No          Rec         167          Unf           0
# 860            No          Unf           0          Unf           0
# 1126           No          Unf           0          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 1023       1330         1346    GasA        Ex          Y      SBrkr
# 810           0         1040    GasA        Fa          Y      SBrkr
# 1384        356          560    GasA        TA          Y      SBrkr
# 626         978          978    GasA        TA          Y      SBrkr
# 813         834         1442    GasA        Gd          Y      SBrkr
# ...         ...          ...     ...       ...        ...        ...
# 1095       1290         1314    GasA        Gd          Y      SBrkr
# 1130        500         1122    GasA        TA          Y      SBrkr
# 1294        697          864    GasA        TA          Y      SBrkr
# 860         912          912    GasA        Gd          Y      SBrkr
# 1126       1373         1373    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 1023      1504         0             0       1504             0             0
# 810       1309         0             0       1309             1             0
# 1384       698       560             0       1258             0             0
# 626       1422         0             0       1422             0             0
# 813       1442         0             0       1442             0             0
# ...        ...       ...           ...        ...           ...           ...
# 1095      1314         0             0       1314             0             0
# 1130      1328       653             0       1981             1             0
# 1294       864         0             0        864             1             0
# 860        912       514             0       1426             0             0
# 1126      1555         0             0       1555             0             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 1023         2         0             2             1          Gd
# 810          1         1             3             1          Gd
# 1384         1         0             2             1          TA
# 626          1         0             3             1          TA
# 813          1         1             4             1          TA
# ...        ...       ...           ...           ...         ...
# 1095         2         0             3             1          Gd
# 1130         2         0             4             1          Gd
# 1294         1         0             2             1          TA
# 860          1         1             3             1          Gd
# 1126         2         0             2             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 1023             7        Typ           1          Gd     Attchd       2005.0
# 810              5        Typ           1          Fa     Attchd       1974.0
# 1384             6        Typ           0         NaN     Detchd       1939.0
# 626              6       Min1           1          TA     Attchd       1960.0
# 813              7        Typ           0         NaN     Attchd       1958.0
# ...            ...        ...         ...         ...        ...          ...
# 1095             6        Typ           1          Gd     Attchd       2006.0
# 1130             7       Min2           2          TA     Detchd       1981.0
# 1294             5        Typ           0         NaN     Detchd       1957.0
# 860              7        Typ           1          Gd     Detchd       1925.0
# 1126             7        Typ           1          TA     Attchd       2007.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 1023          Fin           2         437         TA         TA          Y
# 810           RFn           2         484         TA         TA          Y
# 1384          Unf           1         280         TA         TA          P
# 626           RFn           1         286         TA         TA          Y
# 813           RFn           1         301         TA         TA          Y
# ...           ...         ...         ...        ...        ...        ...
# 1095          RFn           2         440         TA         TA          Y
# 1130          Unf           2         576         TA         TA          Y
# 1294          Unf           2         572         TA         TA          N
# 860           Unf           1         216         TA         TA          Y
# 1126          Fin           3         660         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 1023         156           20              0          0            0
# 810          265            0              0          0            0
# 1384           0            0              0          0            0
# 626            0            0             36          0            0
# 813            0            0            275          0            0
# ...          ...          ...            ...        ...          ...
# 1095           0           22              0          0            0
# 1130         431           44              0          0            0
# 1294           0            0              0          0            0
# 860            0          240              0          0            0
# 1126         143           20              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 1023         0    NaN    NaN         NaN        0       5    2008       WD
# 810        648     Fa  GdPrv         NaN        0       1    2006       WD
# 1384         0    NaN  MnPrv         NaN        0      10    2009       WD
# 626          0    NaN   GdWo        Shed      600       8    2007       WD
# 813          0    NaN    NaN        Shed      500       4    2007      COD
# ...        ...    ...    ...         ...      ...     ...     ...      ...
# 1095         0    NaN    NaN         NaN        0       3    2007       WD
# 1130         0    NaN  MnPrv         NaN        0      12    2009       WD
# 1294         0    NaN    NaN         NaN        0       4    2006       WD
# 860          0    NaN  GdPrv         NaN        0       6    2007       WD
# 1126         0    NaN    NaN         NaN        0       6    2009       WD
#
#      SaleCondition  SalePrice
# 1023        Normal     191000
# 810         Normal     181000
# 1384        Normal     105000
# 626         Normal     139900
# 813         Normal     157900
# ...            ...        ...
# 1095        Normal     176432
# 1130        Normal     135000
# 1294        Normal     115000
# 860         Normal     189950
# 1126        Normal     174000
#
# [1095 rows x 81 columns]

# %% [markdown]
# # 2. Create model

# %% [markdown]
# ## 2.1 Create features

# %%
df_train = feature_engineering(df_train)
df_valid = feature_engineering(df_valid)

# %%
y_train = df_train["SalePrice"]
df_train.drop(columns=["SalePrice"], inplace=True)

y_valid = df_valid["SalePrice"]
df_valid.drop(columns=["SalePrice"], inplace=True)

# %% [markdown]
# ## 2.2 Train model

# %%
feat_cat = df_train.select_dtypes(exclude=['int16', 'int32', 'int64', 'float16', 'float32', 'float64']).columns
feat_cat
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
feat_imp = feature_imputer()
col_transf = column_transformer()



params = {
    'max_iter': 1000,
    'max_depth': 7,
    'categorical_features': feat_cat,
}

estimator = pipe_estimator(feat_imp, col_transf, **params)
estimator
# Out:
# Pipeline(steps=[('feature_imp',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('functional',
#                                                   SimpleImputer(fill_value='Typ',
#                                                                 strategy='constant'),
#                                                   ['Functional']),
#                                                  ('mode',
#                                                   SimpleImputer(strategy='most_frequent'),
#                                                   ['Electrical', 'KitchenQual',
#                                                    'Exterior1st', 'Exterior2nd',
#                                                    'SaleType', 'MSZoning']),
#                                                  ('pool',
#                                                   SimpleImputer(fill_value='No',
#                                                                 strategy='const...
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object'),
#                                                                                     max_depth=7,
#                                                                                     max_iter=1000)))])

# %%
bay_opt = hyperopt_mlflow(
    run_name='opt_bayesian', max_evals=10, alpha=0.2, verbose=0
)

search_space = {
    'model__regressor__learning_rate': hp.loguniform('learning_rate', -5, 0),
    'model__regressor__max_depth': hp.randint('max_depth', 2, 10),
    'model__regressor__l2_regularization': hp.loguniform('l2_regularization', -3, 0),
}


bay_opt.fit(estimator, search_space=search_space, df_train=df_train, y_train=y_train, df_eval=df_valid, y_eval=y_valid)
# Out:
# 2023/12/03 20:00:43 WARNING mlflow.models.signature: Failed to infer the model signature from the input example. Reason: MlflowException("Unable to map 'object' type to MLflow DataType. object can be mapped iff all values have identical data type which is one of (string, (bytes or byterray),  int, float)."). To see the full traceback, set the logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)`. To disable automatic signature inference, set `signature` to `False` in your `log_model` or `save_model` call.
# 2023/12/03 20:00:54 WARNING mlflow.models.signature: Failed to infer the model signature from the input example. Reason: MlflowException("Unable to map 'object' type to MLflow DataType. object can be mapped iff all values have identical data type which is one of (string, (bytes or byterray),  int, float)."). To see the full traceback, set the logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)`. To disable automatic signature inference, set `signature` to `False` in your `log_model` or `save_model` call.
# 2023/12/03 20:00:56 WARNING mlflow.models.signature: Failed to infer the model signature from the input example. Reason: MlflowException("Unable to map 'object' type to MLflow DataType. object can be mapped iff all values have identical data type which is one of (string, (bytes or byterray),  int, float)."). To see the full traceback, set the logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)`. To disable automatic signature inference, set `signature` to `False` in your `log_model` or `save_model` call.
# 2023/12/03 20:01:06 WARNING mlflow.models.signature: Failed to infer the model signature from the input example. Reason: MlflowException("Unable to map 'object' type to MLflow DataType. object can be mapped iff all values have identical data type which is one of (string, (bytes or byterray),  int, float)."). To see the full traceback, set the logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)`. To disable automatic signature inference, set `signature` to `False` in your `log_model` or `save_model` call.
# 2023/12/03 20:01:11 WARNING mlflow.models.signature: Failed to infer the model signature from the input example. Reason: MlflowException("Unable to map 'object' type to MLflow DataType. object can be mapped iff all values have identical data type which is one of (string, (bytes or byterray),  int, float)."). To see the full traceback, set the logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)`. To disable automatic signature inference, set `signature` to `False` in your `log_model` or `save_model` call.
# 2023/12/03 20:01:21 WARNING mlflow.models.signature: Failed to infer the model signature from the input example. Reason: MlflowException("Unable to map 'object' type to MLflow DataType. object can be mapped iff all values have identical data type which is one of (string, (bytes or byterray),  int, float)."). To see the full traceback, set the logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)`. To disable automatic signature inference, set `signature` to `False` in your `log_model` or `save_model` call.
# 2023/12/03 20:01:29 WARNING mlflow.models.signature: Failed to infer the model signature from the input example. Reason: MlflowException("Unable to map 'object' type to MLflow DataType. object can be mapped iff all values have identical data type which is one of (string, (bytes or byterray),  int, float)."). To see the full traceback, set the logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)`. To disable automatic signature inference, set `signature` to `False` in your `log_model` or `save_model` call.
# 2023/12/03 20:01:34 WARNING mlflow.models.signature: Failed to infer the model signature from the input example. Reason: MlflowException("Unable to map 'object' type to MLflow DataType. object can be mapped iff all values have identical data type which is one of (string, (bytes or byterray),  int, float)."). To see the full traceback, set the logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)`. To disable automatic signature inference, set `signature` to `False` in your `log_model` or `save_model` call.
# 2023/12/03 20:01:37 WARNING mlflow.models.signature: Failed to infer the model signature from the input example. Reason: MlflowException("Unable to map 'object' type to MLflow DataType. object can be mapped iff all values have identical data type which is one of (string, (bytes or byterray),  int, float)."). To see the full traceback, set the logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)`. To disable automatic signature inference, set `signature` to `False` in your `log_model` or `save_model` call.
# 2023/12/03 20:01:47 WARNING mlflow.models.signature: Failed to infer the model signature from the input example. Reason: MlflowException("Unable to map 'object' type to MLflow DataType. object can be mapped iff all values have identical data type which is one of (string, (bytes or byterray),  int, float)."). To see the full traceback, set the logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)`. To disable automatic signature inference, set `signature` to `False` in your `log_model` or `save_model` call.

# %%
bay_opt.get_best_params()
# Out:
# {'l2_regularization': 0.11789851812403762,
#  'learning_rate': 0.010924178103679407,
#  'max_depth': 4}
