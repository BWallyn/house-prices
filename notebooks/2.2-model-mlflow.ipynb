# %% [markdown]
# # Create model
#
# # 1. Imports
#
# ## 1.1 Packages

# %%
# Essentials
import os
import numpy as np
import pandas as pd
import sys

# Machine learning

# %%
sys.path.append('../src/house_prices/pipelines/data_science/')
from nodes import feature_engineering, feature_imputer, column_transformer, pipe_estimator
from class_mlflow import mlflow_run

# %% [markdown]
# ## 1.2 Options

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Pandas option
pd.options.display.max_columns = 100

# %%
path_data = '../data/03_primary/'

# %% [markdown]
# ## 1.3 Dataset

# %%
df_train = pd.read_pickle(os.path.join(path_data, 'train_split.pkl'))
df_valid = pd.read_pickle(os.path.join(path_data, 'valid_split.pkl'))
df_train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1023  1024         120       RL         43.0     3182   Pave   NaN      Reg
# 810    811          20       RL         78.0    10140   Pave   NaN      Reg
# 1384  1385          50       RL         60.0     9060   Pave   NaN      Reg
# 626    627          20       RL          NaN    12342   Pave   NaN      IR1
# 813    814          20       RL         75.0     9750   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1095  1096          20       RL         78.0     9317   Pave   NaN      IR1
# 1130  1131          50       RL         65.0     7804   Pave   NaN      Reg
# 1294  1295          20       RL         60.0     8172   Pave   NaN      Reg
# 860    861          50       RL         55.0     7642   Pave   NaN      Reg
# 1126  1127         120       RL         53.0     3684   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1023         Lvl    AllPub    Inside       Gtl      Blmngtn       Norm
# 810          Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 1384         Lvl    AllPub    Inside       Gtl      Edwards       Norm
# 626          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 813          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# ...          ...       ...       ...       ...          ...        ...
# 1095         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1130         Lvl    AllPub    Inside       Gtl        SWISU       Norm
# 1294         Lvl    AllPub    Inside       Gtl      Edwards       Norm
# 860          Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 1126         Lvl    AllPub    Inside       Gtl      Blmngtn       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 1023       Norm   TwnhsE     1Story            7            5       2005
# 810        Norm     1Fam     1Story            6            6       1974
# 1384       Norm     1Fam     1.5Fin            6            5       1939
# 626        Norm     1Fam     1Story            5            5       1960
# 813        Norm     1Fam     1Story            6            6       1958
# ...         ...      ...        ...          ...          ...        ...
# 1095       Norm     1Fam     1Story            6            5       2006
# 1130       Norm     1Fam     1.5Fin            4            3       1928
# 1294       Norm     1Fam     1Story            5            7       1955
# 860        Norm     1Fam     1.5Fin            7            8       1918
# 1126       Norm   TwnhsE     1Story            7            5       2007
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 1023          2006     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 810           1999       Hip  CompShg     HdBoard     HdBoard    BrkFace
# 1384          1950     Gable  CompShg     WdShing     Wd Shng        NaN
# 626           1978       Hip  CompShg     Wd Sdng     Wd Sdng        NaN
# 813           1958     Gable  CompShg     MetalSd     MetalSd    BrkFace
# ...            ...       ...      ...         ...         ...        ...
# 1095          2006     Gable  CompShg     VinylSd     VinylSd        NaN
# 1130          1950     Gable  CompShg     WdShing     Plywood        NaN
# 1294          1990       Hip  CompShg     WdShing     Plywood        NaN
# 860           1998     Gable  CompShg     Wd Sdng     Wd Sdng        NaN
# 1126          2007       Hip  CompShg     VinylSd     VinylSd    BrkFace
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 1023        14.0        Gd        TA      PConc       Gd       Gd
# 810         99.0        TA        TA     CBlock       TA       TA
# 1384         0.0        TA        TA     BrkTil       TA       TA
# 626          0.0        TA        TA     CBlock       TA       TA
# 813        243.0        TA        TA     CBlock       TA       TA
# ...          ...       ...       ...        ...      ...      ...
# 1095         0.0        Gd        TA      PConc       Gd       TA
# 1130         0.0        TA        TA     BrkTil       TA       TA
# 1294         0.0        TA        TA     CBlock       TA       TA
# 860          0.0        Gd        TA     BrkTil       TA       TA
# 1126       130.0        Gd        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 1023           No          GLQ          16          Unf           0
# 810            No          ALQ         663          LwQ         377
# 1384           Mn          Rec         204          Unf           0
# 626            No          Unf           0          Unf           0
# 813            No          Rec         608          Unf           0
# ...           ...          ...         ...          ...         ...
# 1095           No          GLQ          24          Unf           0
# 1130           No          BLQ         622          Unf           0
# 1294           No          Rec         167          Unf           0
# 860            No          Unf           0          Unf           0
# 1126           No          Unf           0          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 1023       1330         1346    GasA        Ex          Y      SBrkr
# 810           0         1040    GasA        Fa          Y      SBrkr
# 1384        356          560    GasA        TA          Y      SBrkr
# 626         978          978    GasA        TA          Y      SBrkr
# 813         834         1442    GasA        Gd          Y      SBrkr
# ...         ...          ...     ...       ...        ...        ...
# 1095       1290         1314    GasA        Gd          Y      SBrkr
# 1130        500         1122    GasA        TA          Y      SBrkr
# 1294        697          864    GasA        TA          Y      SBrkr
# 860         912          912    GasA        Gd          Y      SBrkr
# 1126       1373         1373    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 1023      1504         0             0       1504             0             0
# 810       1309         0             0       1309             1             0
# 1384       698       560             0       1258             0             0
# 626       1422         0             0       1422             0             0
# 813       1442         0             0       1442             0             0
# ...        ...       ...           ...        ...           ...           ...
# 1095      1314         0             0       1314             0             0
# 1130      1328       653             0       1981             1             0
# 1294       864         0             0        864             1             0
# 860        912       514             0       1426             0             0
# 1126      1555         0             0       1555             0             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 1023         2         0             2             1          Gd
# 810          1         1             3             1          Gd
# 1384         1         0             2             1          TA
# 626          1         0             3             1          TA
# 813          1         1             4             1          TA
# ...        ...       ...           ...           ...         ...
# 1095         2         0             3             1          Gd
# 1130         2         0             4             1          Gd
# 1294         1         0             2             1          TA
# 860          1         1             3             1          Gd
# 1126         2         0             2             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 1023             7        Typ           1          Gd     Attchd       2005.0
# 810              5        Typ           1          Fa     Attchd       1974.0
# 1384             6        Typ           0         NaN     Detchd       1939.0
# 626              6       Min1           1          TA     Attchd       1960.0
# 813              7        Typ           0         NaN     Attchd       1958.0
# ...            ...        ...         ...         ...        ...          ...
# 1095             6        Typ           1          Gd     Attchd       2006.0
# 1130             7       Min2           2          TA     Detchd       1981.0
# 1294             5        Typ           0         NaN     Detchd       1957.0
# 860              7        Typ           1          Gd     Detchd       1925.0
# 1126             7        Typ           1          TA     Attchd       2007.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 1023          Fin           2         437         TA         TA          Y
# 810           RFn           2         484         TA         TA          Y
# 1384          Unf           1         280         TA         TA          P
# 626           RFn           1         286         TA         TA          Y
# 813           RFn           1         301         TA         TA          Y
# ...           ...         ...         ...        ...        ...        ...
# 1095          RFn           2         440         TA         TA          Y
# 1130          Unf           2         576         TA         TA          Y
# 1294          Unf           2         572         TA         TA          N
# 860           Unf           1         216         TA         TA          Y
# 1126          Fin           3         660         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 1023         156           20              0          0            0
# 810          265            0              0          0            0
# 1384           0            0              0          0            0
# 626            0            0             36          0            0
# 813            0            0            275          0            0
# ...          ...          ...            ...        ...          ...
# 1095           0           22              0          0            0
# 1130         431           44              0          0            0
# 1294           0            0              0          0            0
# 860            0          240              0          0            0
# 1126         143           20              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 1023         0    NaN    NaN         NaN        0       5    2008       WD
# 810        648     Fa  GdPrv         NaN        0       1    2006       WD
# 1384         0    NaN  MnPrv         NaN        0      10    2009       WD
# 626          0    NaN   GdWo        Shed      600       8    2007       WD
# 813          0    NaN    NaN        Shed      500       4    2007      COD
# ...        ...    ...    ...         ...      ...     ...     ...      ...
# 1095         0    NaN    NaN         NaN        0       3    2007       WD
# 1130         0    NaN  MnPrv         NaN        0      12    2009       WD
# 1294         0    NaN    NaN         NaN        0       4    2006       WD
# 860          0    NaN  GdPrv         NaN        0       6    2007       WD
# 1126         0    NaN    NaN         NaN        0       6    2009       WD
#
#      SaleCondition  SalePrice
# 1023        Normal     191000
# 810         Normal     181000
# 1384        Normal     105000
# 626         Normal     139900
# 813         Normal     157900
# ...            ...        ...
# 1095        Normal     176432
# 1130        Normal     135000
# 1294        Normal     115000
# 860         Normal     189950
# 1126        Normal     174000
#
# [1095 rows x 81 columns]

# %% [markdown]
# # 2. Create model

# %% [markdown]
# ## 2.1 Create features

# %%
df_train = feature_engineering(df_train)
df_valid = feature_engineering(df_valid)

# %%
df_train.sample(5)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 801    802          30       RM         40.0     4800   Pave   NaN      Reg
# 406    407          50       RL         51.0    10480   Pave   NaN      Reg
# 831    832         160       FV         30.0     3180   Pave  Pave      Reg
# 1383  1384          30       RL          NaN    25339   Pave   NaN      Reg
# 145    146         160       RM         24.0     2522   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 801          Lvl    AllPub    Inside       Gtl       IDOTRR       Norm
# 406          Lvl    AllPub    Inside       Gtl        SWISU       Norm
# 831          Lvl    AllPub    Inside       Gtl      Somerst       Norm
# 1383         Lvl    AllPub    Inside       Gtl       Sawyer       Norm
# 145          Lvl    AllPub    Inside       Gtl      Edwards       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 801        Norm     1Fam     1Story            4            7       1916
# 406        Norm     1Fam     1.5Fin            6            5       1936
# 831        Norm   TwnhsE     2Story            7            5       2005
# 1383       Norm     1Fam     1Story            5            7       1918
# 145        Norm    Twnhs     2Story            6            5       2004
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 801           1990     Gable  CompShg     MetalSd     MetalSd        NaN
# 406           1950     Gable  CompShg     MetalSd     MetalSd        NaN
# 831           2005     Gable  CompShg     MetalSd     MetalSd        NaN
# 1383          2007     Gable  CompShg     Wd Sdng     Wd Sdng        NaN
# 145           2006     Gable  CompShg     VinylSd     VinylSd      Stone
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 801          0.0        TA        TA     CBlock       TA       TA
# 406          0.0        TA        TA     BrkTil       TA       TA
# 831          0.0        TA        TA      PConc       Gd       TA
# 1383         0.0        TA        Gd     BrkTil       TA       TA
# 145         50.0        Gd        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 801            No          LwQ         197          Unf           0
# 406            No          Unf           0          Unf           0
# 831            No          Unf           0          Unf           0
# 1383           No          Unf           0          Unf           0
# 145            No          Unf           0          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 801         999       1196.0    GasA        Ex          Y      FuseA
# 406        1064       1064.0    GasA        Ex          Y      FuseA
# 831         600        600.0    GasA        Ex          Y      SBrkr
# 1383        816        816.0    GasA        Ex          Y      SBrkr
# 145         970        970.0    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 801       1196         0             0       1196             1             0
# 406       1166         0           473       1639             0             0
# 831        520       600            80       1200             0             0
# 1383      1416         0             0       1416             0             0
# 145        970       739             0       1709             0             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 801          1         0             2             1          TA
# 406          1         0             3             1          TA
# 831          2         1             2             1          Gd
# 1383         2         0             3             1          Gd
# 145          2         0             3             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 801              5        Typ           0         NaN     Detchd       1957.0
# 406              6       Maj2           0         NaN     Detchd       1936.0
# 831              4        Typ           0         NaN     Detchd       2005.0
# 1383             7        Typ           0         NaN     Attchd       2007.0
# 145              7       Maj1           0         NaN     Detchd       2004.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 801           Unf           2         440         TA         TA          Y
# 406           Unf           1         240         TA         TA          Y
# 831           RFn           2         480         TA         TA          Y
# 1383          Unf           2         576         TA         TA          N
# 145           Unf           2         380         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 801            0            0              0          0            0
# 406            0            0              0          0            0
# 831            0          166              0          0            0
# 1383           0            0            112          0            0
# 145            0           40              0          0            0
#
#       PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 801          0    NaN   NaN         NaN        0       7    2007       WD
# 406          0    NaN   NaN         NaN        0       3    2008       WD
# 831          0    NaN   NaN         NaN        0       6    2006       WD
# 1383         0    NaN   NaN         NaN        0       8    2007       WD
# 145          0    NaN   NaN         NaN        0       4    2006       WD
#
#      SaleCondition  SalePrice  BsmtFinType1_Unf  HasWoodDeck  HasOpenPorch  \
# 801         Normal     109900                 0            1             1
# 406         Normal     115000                 1            1             1
# 831         Normal     151000                 1            1             0
# 1383        Normal     112000                 1            1             1
# 145         Normal     130000                 1            1             0
#
#       HasEnclosedPorch  Has3SsnPorch  HasScreenPorch  haspool  has2ndfloor  \
# 801                  1             1               1        0            0
# 406                  1             1               1        0            0
# 831                  1             1               1        0            1
# 1383                 0             1               1        0            0
# 145                  1             1               1        0            1
#
#       hasgarage  hasbsmt  hasfireplace  YearsSinceRemodel  YrBltAndRemod  \
# 801           1        1             0                 17           3906
# 406           1        1             0                 58           3886
# 831           1        1             0                  1           4010
# 1383          1        1             0                  0           3925
# 145           1        1             0                  0           4010
#
#       Total_Home_Quality  TotalSF  Total_sqr_footage  Total_Bathrooms  \
# 801                   11     2392               1393              2.0
# 406                   11     2230               1166              1.0
# 831                   12     1720               1120              2.5
# 1383                  12     2232               1416              2.0
# 145                   11     2679               1709              2.0
#
#       Total_porch_sf
# 801                0
# 406                0
# 831              166
# 1383             112
# 145               40

# %%
y_train = df_train["SalePrice"]
df_train.drop(columns=["SalePrice"], inplace=True)

y_valid = df_valid["SalePrice"]
df_valid.drop(columns=["SalePrice"], inplace=True)

# %% [markdown]
# ## 2.2 Train model

# %%
feat_cat = df_train.select_dtypes(exclude=['int16', 'int32', 'int64', 'float16', 'float32', 'float64']).columns.tolist()
feat_cat += [
    "BsmtFinType1_Unf", "HasWoodDeck", "HasOpenPorch", "HasEnclosedPorch", "Has3SsnPorch", "HasScreenPorch",
    "haspool", "has2ndfloor", "hasgarage", "hasbsmt", "hasfireplace",
]
print(feat_cat)
# Out:
# ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition', 'BsmtFinType1_Unf', 'HasWoodDeck', 'HasOpenPorch', 'HasEnclosedPorch', 'Has3SsnPorch', 'HasScreenPorch', 'haspool', 'has2ndfloor', 'hasgarage', 'hasbsmt', 'hasfireplace']

# %%
feat_imp = feature_imputer()
col_transf = column_transformer()



params = {
    'max_iter': 1000,
    'max_depth': 5,
    'categorical_features': feat_cat,
    'learning_rate': 0.05,
    'l2_regularization': 0.3,
    'random_state': 42
}

estimator = pipe_estimator(feat_imp, col_transf, **params)
estimator
# Out:
# Pipeline(steps=[('feature_imp',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('functional',
#                                                   SimpleImputer(fill_value='Typ',
#                                                                 strategy='constant'),
#                                                   ['Functional']),
#                                                  ('mode',
#                                                   SimpleImputer(strategy='most_frequent'),
#                                                   ['Electrical', 'KitchenQual',
#                                                    'Exterior1st', 'Exterior2nd',
#                                                    'SaleType', 'MSZoning']),
#                                                  ('pool',
#                                                   SimpleImputer(fill_value='No',
#                                                                 strategy='const...
#                                                                                                           'Condition1',
#                                                                                                           'Condition2',
#                                                                                                           'BldgType',
#                                                                                                           'HouseStyle',
#                                                                                                           'RoofStyle',
#                                                                                                           'RoofMatl',
#                                                                                                           'Exterior1st',
#                                                                                                           'Exterior2nd',
#                                                                                                           'MasVnrType',
#                                                                                                           'ExterQual',
#                                                                                                           'ExterCond',
#                                                                                                           'Foundation',
#                                                                                                           'BsmtQual',
#                                                                                                           'BsmtCond',
#                                                                                                           'BsmtExposure',
#                                                                                                           'BsmtFinType1',
#                                                                                                           'BsmtFinType2',
#                                                                                                           'Heating',
#                                                                                                           'HeatingQC',
#                                                                                                           'CentralAir',
#                                                                                                           'Electrical', ...],
#                                                                                     l2_regularization=0.3,
#                                                                                     learning_rate=0.05,
#                                                                                     max_depth=5,
#                                                                                     max_iter=1000,
#                                                                                     random_state=42)))])

# %%
est_mlflow = mlflow_run(model_name='house-prices', feat=df_train.columns, shap=False)

est_mlflow.fit(
    model=estimator, df_train=df_train, y_train=y_train, df_eval=df_valid, y_eval=y_valid
)
# Out:
# *** Fit model ***
#
# *** Metrics ***
# {'rmse_train': 2765.65736130578, 'rmse_eval': 25790.12913719763}
